# %% [markdown]
# # Challenge 1
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bebeday10/penguin-s-guide-to-python/blob/main/challenge%201.ipynb)
#
# This is *Challenge 1*, where we test your skills.
#
# You are at the *Penguin Library*™ and need to greet your customers.

# %%
customer = "Ben"

print() # TODO: use an f-string to greet Ben.

# %% [markdown]
# Ben wants the third book. Please take and remove the third book from the list and assign it to `ben_book`, and show it to him.

# %%
ben_book: str = "nothing"
books = ["Banana And The King", "Penguin Returns", "Awesome Penguin Books", "Penguin the 4th", "Hills and Eggs"]

# TODO: take the third book from the list and assign it to ben_book

# TODO: show ben his book.

# %% [markdown]
# There's a new book in town. Please add it.

# %%
new_book = "Happy Life on Bananas"

books # TODO: add the new book to the list

print(books)
# Out:
# ['Banana And The King', 'Penguin Returns', 'Awesome Penguin Books', 'Penguin the 4th', 'Hills and Eggs']

# %% [markdown]
# Please tell Ben how many *books* are in your library.

# %%
amount_of_books: int | str = "who knows"

# TODO: assign amount_of_books to the amount of books in the list

print(f"Hello Ben, we currently have {amount_of_books} books.")
# Out:
# Hello Ben!, we currently have who knows books.

# %% [markdown]
# The *penguin boss* asks if there are *less than 3* books.

# %%
# TODO: check if there are less than 3 books, should return True or False.

# %% [markdown]
# A *Kid Penguin*™ asks "What is the remainder of 45 divided by 6?". This shouldn't happen in a library, but they look desperate... Please answer them.

# %%
print() # TODO: answer the kid

# %% [markdown]
# Some penguin asks for the books in the library.

# %%
"""
ROBOT FORMAT:
---
What to do when someone dances: Join them
What to do when a horse comes in: Make them run away
What to do when someone asks for the books in the library: Use the .join method with ", " with the for loop method. (See more on lesson 4 on how to make a list appetizing.)
What to do when someone asks for 10 books: Say you don't have that many books
When to do when someone brings their dog in: Warn the dog that they should not lick the books. If they do, ask them to pay.
---
"""

# TODO: answer the penguin
# Out:
# '\nROBOT FORMAT:\n---\nWhat to do when someone dances: Join them\nWhat to do when a horse comes in: Make them run away\nWhat to do when someone asks for the books in the library: Use the .join method with ", " with the for loop method. (See more on lesson 4 on how to make a list appetizing.)\nWhat to do when someone asks for 10 books: Say you don\'t have that many books\nWhen to do when someone brings their dog in: Warn the dog that they should not lick the books. If they do, ask them to pay.\n---\n'

# %% [markdown]
# The penguin wants the 4th book in the library. Please take it, give it, and show it to them.

# %%
penguin_book = "nothing"

# TODO: take the book and assign it to penguin_book.

# TODO: show the book to the penguin.

# %% [markdown]
# The penguin currently owes 3 books, add 1 more book to make it 4.

# %%
penguin_owes = 3

# TODO: Penguin owes another book. Add it.

# %% [markdown]
# # **Thank you for cooperating with the *Penguin Library*™.**
