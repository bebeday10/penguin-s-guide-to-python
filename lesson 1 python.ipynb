# %% [markdown]
# # Penguins are **bored** and *scared*
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bebeday10/penguin-s-guide-to-python/blob/main/lesson%201%20python.ipynb)
#
#
# Once upon a time, **PENGUINS WERE BORED**. This was extremely *urgent* because of *Situations*™.
#
# # Penguin decided to be an engineer
#
# They proceeded to make a *Robot*™.
# The *Robot*™ was customizable.
# The *Robot*™ could do *Anything*™!
#
# One penguin wants the *Robot*™ to talk.

# %%
print("hello, i am a robot")
# Out:
# hello, i am a robot

# %% [markdown]
# The other wants to do math.

# %%
print(5+4)
# Out:
# 9

# %% [markdown]
# One assigned variables.

# %%
penguin = "banana?"

print(penguin)
# Out:
# banana?

# %% [markdown]
# And there would be much more to discover. On and on and on...
