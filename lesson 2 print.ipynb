# %% [markdown]
# # Robots can talk now apparently
#
# Because of the recent robot making, they can speak now.
#
# They use the `print` penguin, although it doesn't actually print anything to the paper.
#
# The penguins made this for *Communication*™.

# %%
print("hello there")
# Out:
# hello there

# %%
print("hello how are you doing")
# Out:
# hello how are you doing

# %% [markdown]
# These robots are doing exactly what they are supposed to be.
# They will say stuff to the *land of the ice* for penguins to see.

# %%
print("I'm eating a banana!")
# Out:
# I'm eating a banana!

# %%
print("Oh, seriously?")
# Out:
# Oh, seriously?

# %% [markdown]
# The *Robots*™ weren't serious at all.

# %% [markdown]
# # Exercise
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bebeday10/penguin-s-guide-to-python/blob/main/lesson%202%20print.ipynb)
#
# 1. Make the *Robot*™ output
# ```
# I dislike when my pieces get thrown away.
# ```

# %%
print()

# %% [markdown]
# 2. Make the *Robot*™ output the text given.

# %%
"Penguins are great!"
# Out:
# 'Penguins are great!'
