# %% [markdown]
# ## Robots can calculate now, apparently
#
# The robots can also calculate some *Numbers*™.
#
# Some penguins find this useful when doing math.

# %%
5 + 3
# Out:
# 8

# %% [markdown]
# But, in some cases, the robot is *Silent*™. It's deafening.
# Penguins may think they broke it.
#
# Just need it to speak.
#
# How?

# %%
print(5 + 3)
# Out:
# 8

# %% [markdown]
# By talking to the land of ice.

# %% [markdown]
# We can calculate other things as well.

# %%
print(10 + 7) # adding
print(8 * 3) # multiply
print(10 / 4) # division
print(10 // 4) # floor division
print(10 % 4) # the remainder
print(8 ** 3) # power
print(5 * 5 + 3) # uses pemdas

print("I did the thing!")
# Out:
# 17
# 24
# 2.5
# 2
# 2
# 512
# 28
# I did the thing!

# %% [markdown]
# The penguins now have their own calculator.

# %% [markdown]
# # Exercise
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bebeday10/penguin-s-guide-to-python/blob/main/lesson%203%20MATH.ipynb)
#
# What's 12 plus 5? No penguin knows. Use the robot.

# %%
print() # TODO: calculate 12 plus 5 (no penguin knows)

# %% [markdown]
# *A penguin train* is going to street 3 to the power of 4. *Where is that street?*

# %%
print() # TODO: calculate 3 to the power of 4 (idk what powers are)

# %% [markdown]
# Welcome to math class. What's 10 times 2 minus 5?

# %%
print() # TODO: calculate 10 times 2 minus 5 (it's really hard)
